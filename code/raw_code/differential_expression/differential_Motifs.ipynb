# %%
suppressMessages(library(ArchR))
ss <- function(x, pattern, slot = 1, ...) { sapply(strsplit(x = x, split = pattern, ...), '[', slot) }
options(stringsAsFactors = F)
options(repr.plot.width=11, repr.plot.height=8.5)

# %%
##################################
### set Arrow File parameters ####
addArchRThreads(threads = 12)

##################################
### load rheMac10 ArchR genome ###
GENOMEDIR='/home/bnphan/resources/genomes/rheMac10'
load(file.path(GENOMEDIR,'rheMac10_liftoff_GRCh38.p13_ArchR_annotations.rda'))
# Out:
# Setting default number of Parallel threads to 12.

# %%
PROJDIR='../../../data/tidy_data/ArchRProjects'
proj = loadArchRProject(file.path(PROJDIR,'Rat_Transgen_NAc_scATAC_clusterRat'), showLogo = FALSE)
# Out:
# Successfully loaded ArchRProject!

# %%
for (cellType in proj$cluster_rat_RNA2ATAC %>% sort() %>% unique()){
    
    print(cellType)
}

idxSample <- BiocGenerics::which(proj$cluster_rat_RNA2ATAC %in% cellType )

# create instantaneous subset
proj2 = subsetCells(proj, proj$cellNames[idxSample])
table(proj2$cluster_rat_RNA2ATAC[idxSample])
# Out:
# [1] "Astrocytes"
# [1] "D1-ICj-MSN"
# [1] "D1-MSN"
# [1] "D1-NUDAP-MSN"
# [1] "D1/D2-Hybrid-MSN"
# [1] "D1/D3-MSN"
# [1] "D2-MSN"
# [1] "Microglia"
# [1] "Oligos"
# [1] "Oligos_Pre"
# [1] "Pvalb-INT"
# [1] "Sst-INT"
# Sst-INT
#       1

# %%
# Use a for-loop for all the cell types
for (cellType in proj$cluster_rat_RNA2ATAC %>% sort() %>% unique()){
    #load in the cell type seperately in a subset
    idxSample <- BiocGenerics::which(proj$cluster_rat_RNA2ATAC %in% cellType ) 
    proj2 = subsetCells(proj, proj$cellNames[idxSample])
    
    #Use getMarkerFeaturs 
    markerTest_CvS <- getMarkerFeatures(
    ArchRProj = proj2, 
    useMatrix = "MotifMatrix",
    groupBy = "Sire",
    testMethod = "wilcoxon",
    bias = c("TSSEnrichment", "log10(nFrags)"),
    useGroups = "Cocaine",
    bgdGroups = "Saline")
       
    markerTest_MvS <- getMarkerFeatures(
    ArchRProj = proj2, 
    useMatrix = "MotifMatrix",
    groupBy = "Sire",
    testMethod = "wilcoxon",
    bias = c("TSSEnrichment", "log10(nFrags)"),
    useGroups = "Methamphetamine",
    bgdGroups = "Saline")
    
    markerTest_MvC <- getMarkerFeatures(
    ArchRProj = proj2, 
    useMatrix = "MotifMatrix",
    groupBy = "Sire",
    testMethod = "wilcoxon",
    bias = c("TSSEnrichment", "log10(nFrags)"),
    useGroups = "Methamphetamine",
    bgdGroups = "Cocaine")
    
    
    test_list = list('Cocaine_v_Saline' = markerTest_CvS,
                'Meth_v_Saline' = markerTest_MvS, 'Meth_v_Cocaine' = markerTest_MvC)
    saveDir = "../../../data"
    path = file.path(saveDir, paste0('differential_MotifMatrix.', make.names(cellType), '.rds'))
    saveRDS(test_list, path)


}
# Out:
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e646c7459-Date-2023-02-23_Time-23-57-35.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:57:37 :
#
# 2023-02-23 23:57:37 : Matching Known Biases, 0.033 mins elapsed.
#
# 2023-02-23 23:57:37 : Computing Pairwise Tests (1 of 1), 0.037 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-23 23:57:41 : Completed Pairwise Tests, 0.097 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e646c7459-Date-2023-02-23_Time-23-57-35.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e5d30bc25-Date-2023-02-23_Time-23-57-41.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:57:41 :
#
# 2023-02-23 23:57:41 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:57:42 : Computing Pairwise Tests (1 of 1), 0.007 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:57:43 : Completed Pairwise Tests, 0.026 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e5d30bc25-Date-2023-02-23_Time-23-57-41.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e23d152c7-Date-2023-02-23_Time-23-57-43.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:57:43 :
#
# 2023-02-23 23:57:43 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:57:43 : Computing Pairwise Tests (1 of 1), 0.007 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:57:45 : Completed Pairwise Tests, 0.038 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e23d152c7-Date-2023-02-23_Time-23-57-43.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e45d487d1-Date-2023-02-23_Time-23-58-12.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:58:13 :
#
# 2023-02-23 23:58:13 : Matching Known Biases, 0.002 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 5
#
# 2023-02-23 23:58:13 :
#
# 2023-02-23 23:58:13 : Computing Pairwise Tests (1 of 1), 0.003 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-23 23:58:14 : Completed Pairwise Tests, 0.019 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e45d487d1-Date-2023-02-23_Time-23-58-12.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e34ff552-Date-2023-02-23_Time-23-58-14.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:58:14 :
#
# 2023-02-23 23:58:14 : Matching Known Biases, 0.001 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 5
#
# 2023-02-23 23:58:14 :
#
# 2023-02-23 23:58:14 : Computing Pairwise Tests (1 of 1), 0.002 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:58:16 : Completed Pairwise Tests, 0.036 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e34ff552-Date-2023-02-23_Time-23-58-14.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e38493f68-Date-2023-02-23_Time-23-58-16.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:58:16 :
#
# 2023-02-23 23:58:16 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:58:16 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:58:18 : Completed Pairwise Tests, 0.035 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e38493f68-Date-2023-02-23_Time-23-58-16.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e11c9b965-Date-2023-02-23_Time-23-58-44.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:58:44 :
#
# 2023-02-23 23:58:44 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:58:45 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-23 23:58:49 : Completed Pairwise Tests, 0.071 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e11c9b965-Date-2023-02-23_Time-23-58-44.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8ee700d98-Date-2023-02-23_Time-23-58-49.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:58:49 :
#
# 2023-02-23 23:58:49 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:58:49 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:58:50 : Completed Pairwise Tests, 0.025 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8ee700d98-Date-2023-02-23_Time-23-58-49.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e6879c2f3-Date-2023-02-23_Time-23-58-50.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:58:51 :
#
# 2023-02-23 23:58:51 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:58:51 : Computing Pairwise Tests (1 of 1), 0.003 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:58:52 : Completed Pairwise Tests, 0.024 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e6879c2f3-Date-2023-02-23_Time-23-58-50.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e4ad7002b-Date-2023-02-23_Time-23-59-21.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
# 2023-02-23 23:59:21 :
#
# 2023-02-23 23:59:21 : Matching Known Biases, 0.001 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 70
#
# 2023-02-23 23:59:21 :
#
# 2023-02-23 23:59:23 : Computing Pairwise Tests (1 of 1), 0.035 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-23 23:59:24 : Completed Pairwise Tests, 0.051 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e4ad7002b-Date-2023-02-23_Time-23-59-21.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e39953b62-Date-2023-02-23_Time-23-59-24.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:59:24 :
#
# 2023-02-23 23:59:24 : Matching Known Biases, 0.001 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 70
#
# 2023-02-23 23:59:24 :
#
# 2023-02-23 23:59:24 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:59:26 : Completed Pairwise Tests, 0.038 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e39953b62-Date-2023-02-23_Time-23-59-24.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e222439c-Date-2023-02-23_Time-23-59-26.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:59:27 :
#
# 2023-02-23 23:59:27 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:59:27 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:59:29 : Completed Pairwise Tests, 0.039 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e222439c-Date-2023-02-23_Time-23-59-26.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e1cde5062-Date-2023-02-23_Time-23-59-55.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:59:55 :
#
# 2023-02-23 23:59:55 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:59:55 : Computing Pairwise Tests (1 of 1), 0.003 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-23 23:59:56 : Completed Pairwise Tests, 0.018 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e1cde5062-Date-2023-02-23_Time-23-59-55.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e4c8c3a2c-Date-2023-02-23_Time-23-59-56.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:59:56 :
#
# 2023-02-23 23:59:56 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:59:57 : Computing Pairwise Tests (1 of 1), 0.005 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-23 23:59:59 : Completed Pairwise Tests, 0.039 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e4c8c3a2c-Date-2023-02-23_Time-23-59-56.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e7cbb0e61-Date-2023-02-23_Time-23-59-59.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-23 23:59:59 :
#
# 2023-02-23 23:59:59 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-23 23:59:59 : Computing Pairwise Tests (1 of 1), 0.005 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:00:00 : Completed Pairwise Tests, 0.022 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e7cbb0e61-Date-2023-02-23_Time-23-59-59.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e5cad489c-Date-2023-02-24_Time-00-00-28.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:00:28 :
#
# 2023-02-24 00:00:28 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:00:29 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-24 00:00:31 : Completed Pairwise Tests, 0.037 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e5cad489c-Date-2023-02-24_Time-00-00-28.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e1da6d630-Date-2023-02-24_Time-00-00-31.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:00:31 :
#
# 2023-02-24 00:00:31 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:00:31 : Computing Pairwise Tests (1 of 1), 0.005 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:00:33 : Completed Pairwise Tests, 0.04 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e1da6d630-Date-2023-02-24_Time-00-00-31.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e7c8d310d-Date-2023-02-24_Time-00-00-33.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:00:33 :
#
# 2023-02-24 00:00:33 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:00:34 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:00:35 : Completed Pairwise Tests, 0.036 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e7c8d310d-Date-2023-02-24_Time-00-00-33.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e4d4f3b58-Date-2023-02-24_Time-00-01-02.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:01:02 :
#
# 2023-02-24 00:01:02 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:01:02 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-24 00:01:03 : Completed Pairwise Tests, 0.024 mins elapsed.
# ###########
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e4d4f3b58-Date-2023-02-24_Time-00-01-02.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e3bdc7b83-Date-2023-02-24_Time-00-01-03.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:01:03 :
#
# 2023-02-24 00:01:03 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:01:03 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:01:05 : Completed Pairwise Tests, 0.024 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e3bdc7b83-Date-2023-02-24_Time-00-01-03.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e4ba23a17-Date-2023-02-24_Time-00-01-05.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:01:05 :
#
# 2023-02-24 00:01:05 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:01:05 : Computing Pairwise Tests (1 of 1), 0.003 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:01:08 : Completed Pairwise Tests, 0.044 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e4ba23a17-Date-2023-02-24_Time-00-01-05.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e7bf1bdda-Date-2023-02-24_Time-00-01-35.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:01:35 :
#
# 2023-02-24 00:01:35 : Matching Known Biases, 0.002 mins elapsed.
#
# 2023-02-24 00:01:35 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-24 00:01:36 : Completed Pairwise Tests, 0.023 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e7bf1bdda-Date-2023-02-24_Time-00-01-35.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e26a687e5-Date-2023-02-24_Time-00-01-36.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:01:36 :
#
# 2023-02-24 00:01:36 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:01:36 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:01:41 : Completed Pairwise Tests, 0.072 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e26a687e5-Date-2023-02-24_Time-00-01-36.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e78881010-Date-2023-02-24_Time-00-01-41.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:01:41 :
#
# 2023-02-24 00:01:41 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:01:41 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:01:42 : Completed Pairwise Tests, 0.022 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e78881010-Date-2023-02-24_Time-00-01-41.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e67e2a64b-Date-2023-02-24_Time-00-02-08.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:02:09 :
#
# 2023-02-24 00:02:09 : Matching Known Biases, 0.003 mins elapsed.
#
# 2023-02-24 00:02:09 : Computing Pairwise Tests (1 of 1), 0.004 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-24 00:02:10 : Completed Pairwise Tests, 0.028 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e67e2a64b-Date-2023-02-24_Time-00-02-08.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e71ea642b-Date-2023-02-24_Time-00-02-10.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:02:10 :
#
# 2023-02-24 00:02:10 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:02:12 : Computing Pairwise Tests (1 of 1), 0.025 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:02:14 : Completed Pairwise Tests, 0.062 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e71ea642b-Date-2023-02-24_Time-00-02-10.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e1804d040-Date-2023-02-24_Time-00-02-14.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:02:14 :
#
# 2023-02-24 00:02:14 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:02:15 : Computing Pairwise Tests (1 of 1), 0.009 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:02:16 : Completed Pairwise Tests, 0.027 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e1804d040-Date-2023-02-24_Time-00-02-14.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e2b3921e7-Date-2023-02-24_Time-00-02-42.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:02:42 :
#
# 2023-02-24 00:02:42 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:02:42 : Computing Pairwise Tests (1 of 1), 0.003 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-24 00:02:43 : Completed Pairwise Tests, 0.021 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e2b3921e7-Date-2023-02-24_Time-00-02-42.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e5400138a-Date-2023-02-24_Time-00-02-43.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
# 2023-02-24 00:02:43 :
#
# 2023-02-24 00:02:43 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:02:44 : Computing Pairwise Tests (1 of 1), 0.003 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:02:45 : Completed Pairwise Tests, 0.022 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e5400138a-Date-2023-02-24_Time-00-02-43.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e79fd7e01-Date-2023-02-24_Time-00-02-45.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:02:45 :
#
# 2023-02-24 00:02:45 : Matching Known Biases, 0.001 mins elapsed.
#
# 2023-02-24 00:02:45 : Computing Pairwise Tests (1 of 1), 0.005 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:02:48 : Completed Pairwise Tests, 0.054 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e79fd7e01-Date-2023-02-24_Time-00-02-45.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e5af63cc2-Date-2023-02-24_Time-00-03-14.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:03:14 :
#
# 2023-02-24 00:03:14 : Matching Known Biases, 0.001 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 13
#
# 2023-02-24 00:03:14 :
#
# 2023-02-24 00:03:14 : Computing Pairwise Tests (1 of 1), 0.003 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-24 00:03:16 : Completed Pairwise Tests, 0.032 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e5af63cc2-Date-2023-02-24_Time-00-03-14.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e2de501c3-Date-2023-02-24_Time-00-03-16.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:03:16 :
#
# 2023-02-24 00:03:16 : Matching Known Biases, 0.001 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 13
#
# 2023-02-24 00:03:16 :
#
# 2023-02-24 00:03:16 : Computing Pairwise Tests (1 of 1), 0.002 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:03:19 : Completed Pairwise Tests, 0.04 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e2de501c3-Date-2023-02-24_Time-00-03-16.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e703e0d53-Date-2023-02-24_Time-00-03-19.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:03:19 :
#
# 2023-02-24 00:03:19 : Matching Known Biases, 0.001 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 43
#
# 2023-02-24 00:03:19 :
#
# 2023-02-24 00:03:19 : Computing Pairwise Tests (1 of 1), 0.002 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:03:20 : Completed Pairwise Tests, 0.019 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e703e0d53-Date-2023-02-24_Time-00-03-19.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e6671e14a-Date-2023-02-24_Time-00-03-46.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:03:46 :
#
# 2023-02-24 00:03:46 : Matching Known Biases, 0.002 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 15
#
# 2023-02-24 00:03:46 :
#
# 2023-02-24 00:03:46 : Computing Pairwise Tests (1 of 1), 0.003 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames deviations
#
# ###########
# 2023-02-24 00:03:47 : Completed Pairwise Tests, 0.019 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e6671e14a-Date-2023-02-24_Time-00-03-46.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e3b8dd8be-Date-2023-02-24_Time-00-03-47.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:03:47 :
#
# 2023-02-24 00:03:47 : Matching Known Biases, 0.001 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 15
#
# 2023-02-24 00:03:47 :
#
# 2023-02-24 00:03:48 : Computing Pairwise Tests (1 of 1), 0.002 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:03:50 : Completed Pairwise Tests, 0.039 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e3b8dd8be-Date-2023-02-24_Time-00-03-47.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-24c8e74ae195a-Date-2023-02-24_Time-00-03-50.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'deviations'!
# If confused, try getSeqnames(ArchRProj, 'MotifMatrix'') to list out available seqnames for input!
#
# 2023-02-24 00:03:50 :
#
# 2023-02-24 00:03:50 : Matching Known Biases, 0.001 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 49
#
# 2023-02-24 00:03:50 :
#
# 2023-02-24 00:03:50 : Computing Pairwise Tests (1 of 1), 0.002 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames deviations
#
# ###########
# 2023-02-24 00:03:51 : Completed Pairwise Tests, 0.019 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-24c8e74ae195a-Date-2023-02-24_Time-00-03-50.log
