# %%
suppressMessages(library(ArchR))
ss <- function(x, pattern, slot = 1, ...) { sapply(strsplit(x = x, split = pattern, ...), '[', slot) }
options(stringsAsFactors = F)
options(repr.plot.width=11, repr.plot.height=8.5)

# %%
##################################
### set Arrow File parameters ####
addArchRThreads(threads = 12)

##################################
### load rheMac10 ArchR genome ###
GENOMEDIR='/home/bnphan/resources/genomes/rheMac10'
load(file.path(GENOMEDIR,'rheMac10_liftoff_GRCh38.p13_ArchR_annotations.rda'))
# Out:
# Setting default number of Parallel threads to 12.

# %%
PROJDIR='../../../data/tidy_data/ArchRProjects'
proj = loadArchRProject(file.path(PROJDIR,'Rat_Transgen_NAc_scATAC_clusterRat'), showLogo = FALSE)
# Out:
# Successfully loaded ArchRProject!

# %%
table(proj$cluster_rat_RNA2ATAC)
head(getCellColData(proj),1)
# Out:
#       Astrocytes       D1-ICj-MSN           D1-MSN     D1-NUDAP-MSN
#              898              414             2165              495
# D1/D2-Hybrid-MSN        D1/D3-MSN           D2-MSN        Microglia
#              604              870             2461              525
#           Oligos       Oligos_Pre        Pvalb-INT          Sst-INT
#             1416              942               73               96
# DataFrame with 1 row and 24 columns
#                            Sample TSSEnrichment ReadsInTSS ReadsInPromoter
#                       <character>     <numeric>  <numeric>       <numeric>
# 1S#TTGTGCCTCCTGTTCA-1          1S          4.66        913            6950
#                       ReadsInBlacklist PromoterRatio    PassQC NucleosomeRatio
#                              <numeric>     <numeric> <numeric>       <numeric>
# 1S#TTGTGCCTCCTGTTCA-1                7     0.0666833         1          1.3308
#                       nMultiFrags nMonoFrags    nFrags  nDiFrags DoubletScore
#                         <numeric>  <numeric> <numeric> <numeric>    <numeric>
# 1S#TTGTGCCTCCTGTTCA-1        8545      22358     52112     21209            0
#                       DoubletEnrichment BlacklistRatio        Sire
#                               <numeric>      <numeric> <character>
# 1S#TTGTGCCTCCTGTTCA-1          0.464516     6.7163e-05      Saline
#                       ClustersI200_ATAC ClustersH200_ATAC logNFrags   Celltype1
#                             <character>       <character> <numeric> <character>
# 1S#TTGTGCCTCCTGTTCA-1               C10                C5   4.71694      Neuron
#                       cluster_rat_RNA2ATAC cluster_macaque_RNA2ATAC
#                                <character>              <character>
# 1S#TTGTGCCTCCTGTTCA-1               D2-MSN                 D2.Shell
#                       ReadsInPeaks      FRIP
#                          <numeric> <numeric>
# 1S#TTGTGCCTCCTGTTCA-1        28285  0.271496

# %%
for (cellType in proj$cluster_rat_RNA2ATAC %>% sort() %>% unique()){
    
    print(cellType)
}

idxSample <- BiocGenerics::which(proj$cluster_rat_RNA2ATAC %in% cellType )

# create instantaneous subset
proj2 = subsetCells(proj, proj$cellNames[idxSample])
table(proj2$cluster_rat_RNA2ATAC[idxSample])
# Out:
# [1] "Astrocytes"
# [1] "D1-ICj-MSN"
# [1] "D1-MSN"
# [1] "D1-NUDAP-MSN"
# [1] "D1/D2-Hybrid-MSN"
# [1] "D1/D3-MSN"
# [1] "D2-MSN"
# [1] "Microglia"
# [1] "Oligos"
# [1] "Oligos_Pre"
# [1] "Pvalb-INT"
# [1] "Sst-INT"
# Sst-INT
#       1

# %%
# Use a for-loop for all the cell types
for (cellType in proj$cluster_rat_RNA2ATAC %>% sort() %>% unique()){
    #load in the cell type seperately in a subset
    idxSample <- BiocGenerics::which(proj$cluster_rat_RNA2ATAC %in% cellType ) 
    proj2 = subsetCells(proj, proj$cellNames[idxSample])
    
    #Use getMarkerFeaturs 
    markerTest_CvS <- getMarkerFeatures(
    ArchRProj = proj2, 
    useMatrix = "PeakMatrix",
    groupBy = "Sire",
    testMethod = "wilcoxon",
    bias = c("TSSEnrichment", "log10(nFrags)"),
    useGroups = "Cocaine",
    bgdGroups = "Saline",
    maxCells = 1000)
       
    markerTest_MvS <- getMarkerFeatures(
    ArchRProj = proj2, 
    useMatrix = "PeakMatrix",
    groupBy = "Sire",
    testMethod = "wilcoxon",
    bias = c("TSSEnrichment", "log10(nFrags)"),
    useGroups = "Methamphetamine",
    bgdGroups = "Saline",
    maxCells = 1000)
    
    markerTest_MvC <- getMarkerFeatures(
    ArchRProj = proj2, 
    useMatrix = "PeakMatrix",
    groupBy = "Sire",
    testMethod = "wilcoxon",
    bias = c("TSSEnrichment", "log10(nFrags)"),
    useGroups = "Methamphetamine",
    bgdGroups = "Cocaine",
    maxCells = 1000)
    
    
    test_list = list('Cocaine_v_Saline' = markerTest_CvS,
                'Meth_v_Saline' = markerTest_MvS, 'Meth_v_Cocaine' = markerTest_MvC)
    saveDir = "../../../data/new_differential_Peaks_data"
    path = file.path(saveDir, paste0('differential_PeakMatrix.', make.names(cellType), '.rds'))
    saveRDS(test_list, path)


}
# Out:
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc73e2141d5-Date-2023-04-18_Time-21-31-49.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:31:53 : Matching Known Biases, 0.058 mins elapsed.
#
# 2023-04-18 21:32:00 : Computing Pairwise Tests (1 of 1), 0.169 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 21:32:48 : Completed Pairwise Tests, 0.975 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc73e2141d5-Date-2023-04-18_Time-21-31-49.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc728bf0372-Date-2023-04-18_Time-21-32-50.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:32:52 : Matching Known Biases, 0.037 mins elapsed.
#
# 2023-04-18 21:32:57 : Computing Pairwise Tests (1 of 1), 0.12 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:33:47 : Completed Pairwise Tests, 0.956 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc728bf0372-Date-2023-04-18_Time-21-32-50.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7132fd02a-Date-2023-04-18_Time-21-33-48.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:33:50 : Matching Known Biases, 0.03 mins elapsed.
#
# 2023-04-18 21:33:53 : Computing Pairwise Tests (1 of 1), 0.083 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:34:38 : Completed Pairwise Tests, 0.832 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7132fd02a-Date-2023-04-18_Time-21-33-48.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc737c5c6c4-Date-2023-04-18_Time-21-35-13.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:35:15 : Matching Known Biases, 0.027 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 5
#
# 2023-04-18 21:35:15 :
#
# 2023-04-18 21:35:18 : Computing Pairwise Tests (1 of 1), 0.082 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 21:35:50 : Completed Pairwise Tests, 0.626 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc737c5c6c4-Date-2023-04-18_Time-21-35-13.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7587dc290-Date-2023-04-18_Time-21-35-53.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:35:54 : Matching Known Biases, 0.026 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 5
#
# 2023-04-18 21:35:54 :
#
# 2023-04-18 21:35:57 : Computing Pairwise Tests (1 of 1), 0.078 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:36:38 : Completed Pairwise Tests, 0.749 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7587dc290-Date-2023-04-18_Time-21-35-53.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc766971618-Date-2023-04-18_Time-21-36-39.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:36:40 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 21:36:43 : Computing Pairwise Tests (1 of 1), 0.064 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:37:25 : Completed Pairwise Tests, 0.754 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc766971618-Date-2023-04-18_Time-21-36-39.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc71260dec6-Date-2023-04-18_Time-21-37-55.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:37:57 : Matching Known Biases, 0.036 mins elapsed.
#
# 2023-04-18 21:37:59 : Computing Pairwise Tests (1 of 1), 0.07 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 21:39:05 : Completed Pairwise Tests, 1.169 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc71260dec6-Date-2023-04-18_Time-21-37-55.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7345b2d04-Date-2023-04-18_Time-21-39-09.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:39:11 : Matching Known Biases, 0.032 mins elapsed.
#
# 2023-04-18 21:39:17 : Computing Pairwise Tests (1 of 1), 0.124 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:40:08 : Completed Pairwise Tests, 0.979 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7345b2d04-Date-2023-04-18_Time-21-39-09.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc73a006959-Date-2023-04-18_Time-21-40-09.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:40:10 : Matching Known Biases, 0.009 mins elapsed.
#
# 2023-04-18 21:40:15 : Computing Pairwise Tests (1 of 1), 0.088 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:41:08 : Completed Pairwise Tests, 0.985 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc73a006959-Date-2023-04-18_Time-21-40-09.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc716ac1e3f-Date-2023-04-18_Time-21-41-41.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:41:44 : Matching Known Biases, 0.034 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 70
#
# 2023-04-18 21:41:44 :
#
# 2023-04-18 21:41:47 : Computing Pairwise Tests (1 of 1), 0.093 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 21:42:35 : Completed Pairwise Tests, 0.889 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc716ac1e3f-Date-2023-04-18_Time-21-41-41.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7981782b-Date-2023-04-18_Time-21-42-36.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:42:37 : Matching Known Biases, 0.008 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 70
#
# 2023-04-18 21:42:37 :
#
# 2023-04-18 21:42:43 : Computing Pairwise Tests (1 of 1), 0.109 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:43:35 : Completed Pairwise Tests, 0.97 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7981782b-Date-2023-04-18_Time-21-42-36.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc76180bf28-Date-2023-04-18_Time-21-43-36.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:43:36 : Matching Known Biases, 0.007 mins elapsed.
#
# 2023-04-18 21:43:40 : Computing Pairwise Tests (1 of 1), 0.065 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:44:29 : Completed Pairwise Tests, 0.879 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc76180bf28-Date-2023-04-18_Time-21-43-36.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc711a47766-Date-2023-04-18_Time-21-45-04.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:45:05 : Matching Known Biases, 0.01 mins elapsed.
#
# 2023-04-18 21:45:10 : Computing Pairwise Tests (1 of 1), 0.093 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 21:45:53 : Completed Pairwise Tests, 0.801 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc711a47766-Date-2023-04-18_Time-21-45-04.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc76d478e23-Date-2023-04-18_Time-21-45-56.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:45:57 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 21:46:00 : Computing Pairwise Tests (1 of 1), 0.07 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:46:44 : Completed Pairwise Tests, 0.795 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc76d478e23-Date-2023-04-18_Time-21-45-56.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc771e406bd-Date-2023-04-18_Time-21-46-46.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:46:47 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 21:46:53 : Computing Pairwise Tests (1 of 1), 0.118 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:47:40 : Completed Pairwise Tests, 0.899 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc771e406bd-Date-2023-04-18_Time-21-46-46.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7799f76e6-Date-2023-04-18_Time-21-48-14.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:48:21 : Matching Known Biases, 0.064 mins elapsed.
#
# 2023-04-18 21:48:26 : Computing Pairwise Tests (1 of 1), 0.15 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 21:49:08 : Completed Pairwise Tests, 0.854 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7799f76e6-Date-2023-04-18_Time-21-48-14.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc79e47a00-Date-2023-04-18_Time-21-49-10.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:49:11 : Matching Known Biases, 0.009 mins elapsed.
#
# 2023-04-18 21:49:16 : Computing Pairwise Tests (1 of 1), 0.087 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:50:06 : Completed Pairwise Tests, 0.921 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc79e47a00-Date-2023-04-18_Time-21-49-10.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7433ee6f2-Date-2023-04-18_Time-21-50-07.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:50:10 : Matching Known Biases, 0.007 mins elapsed.
#
# 2023-04-18 21:50:15 : Computing Pairwise Tests (1 of 1), 0.091 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:51:09 : Completed Pairwise Tests, 0.983 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7433ee6f2-Date-2023-04-18_Time-21-50-07.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7674cbc07-Date-2023-04-18_Time-21-51-43.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:51:45 : Matching Known Biases, 0.033 mins elapsed.
#
# 2023-04-18 21:51:50 : Computing Pairwise Tests (1 of 1), 0.116 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 21:52:34 : Completed Pairwise Tests, 0.853 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7674cbc07-Date-2023-04-18_Time-21-51-43.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc75f7c48a2-Date-2023-04-18_Time-21-52-37.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:52:40 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 21:52:49 : Computing Pairwise Tests (1 of 1), 0.161 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:53:47 : Completed Pairwise Tests, 1.124 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc75f7c48a2-Date-2023-04-18_Time-21-52-37.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc715bd6788-Date-2023-04-18_Time-21-53-48.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:53:50 : Matching Known Biases, 0.03 mins elapsed.
#
# 2023-04-18 21:53:55 : Computing Pairwise Tests (1 of 1), 0.113 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:54:45 : Completed Pairwise Tests, 0.943 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc715bd6788-Date-2023-04-18_Time-21-53-48.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc72e2046d4-Date-2023-04-18_Time-21-55-17.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:55:20 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 21:55:23 : Computing Pairwise Tests (1 of 1), 0.065 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
# ###########
# 2023-04-18 21:56:09 : Completed Pairwise Tests, 0.841 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc72e2046d4-Date-2023-04-18_Time-21-55-17.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7567af887-Date-2023-04-18_Time-21-56-11.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:56:14 : Matching Known Biases, 0.039 mins elapsed.
#
# 2023-04-18 21:56:20 : Computing Pairwise Tests (1 of 1), 0.142 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:57:08 : Completed Pairwise Tests, 0.949 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7567af887-Date-2023-04-18_Time-21-56-11.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc751dd5882-Date-2023-04-18_Time-21-57-09.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:57:10 : Matching Known Biases, 0.009 mins elapsed.
#
# 2023-04-18 21:57:15 : Computing Pairwise Tests (1 of 1), 0.085 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 21:58:07 : Completed Pairwise Tests, 0.952 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc751dd5882-Date-2023-04-18_Time-21-57-09.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc710852c74-Date-2023-04-18_Time-21-58-40.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:58:41 : Matching Known Biases, 0.02 mins elapsed.
#
# 2023-04-18 21:58:46 : Computing Pairwise Tests (1 of 1), 0.101 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 21:59:31 : Completed Pairwise Tests, 0.843 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc710852c74-Date-2023-04-18_Time-21-58-40.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc768428921-Date-2023-04-18_Time-21-59-33.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 21:59:34 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 21:59:37 : Computing Pairwise Tests (1 of 1), 0.062 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 22:00:23 : Completed Pairwise Tests, 0.816 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc768428921-Date-2023-04-18_Time-21-59-33.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc73db2b30b-Date-2023-04-18_Time-22-00-24.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:00:25 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 22:00:31 : Computing Pairwise Tests (1 of 1), 0.102 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 22:01:15 : Completed Pairwise Tests, 0.85 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc73db2b30b-Date-2023-04-18_Time-22-00-24.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7544c85-Date-2023-04-18_Time-22-01-49.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:01:51 : Matching Known Biases, 0.034 mins elapsed.
#
# 2023-04-18 22:01:54 : Computing Pairwise Tests (1 of 1), 0.091 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 22:02:39 : Completed Pairwise Tests, 0.837 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7544c85-Date-2023-04-18_Time-22-01-49.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc76f50a5e-Date-2023-04-18_Time-22-02-42.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:02:44 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 22:02:50 : Computing Pairwise Tests (1 of 1), 0.094 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 22:03:37 : Completed Pairwise Tests, 0.881 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc76f50a5e-Date-2023-04-18_Time-22-02-42.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc77b0ff6bc-Date-2023-04-18_Time-22-03-38.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:03:39 : Matching Known Biases, 0.008 mins elapsed.
#
# 2023-04-18 22:03:44 : Computing Pairwise Tests (1 of 1), 0.096 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 22:04:30 : Completed Pairwise Tests, 0.867 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc77b0ff6bc-Date-2023-04-18_Time-22-03-38.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7103856f6-Date-2023-04-18_Time-22-05-03.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:05:03 : Matching Known Biases, 0.009 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 13
#
# 2023-04-18 22:05:04 :
#
# 2023-04-18 22:05:09 : Computing Pairwise Tests (1 of 1), 0.093 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 22:05:54 : Completed Pairwise Tests, 0.849 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc7103856f6-Date-2023-04-18_Time-22-05-03.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc71e095066-Date-2023-04-18_Time-22-05-55.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:05:56 : Matching Known Biases, 0.008 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 13
#
# 2023-04-18 22:05:56 :
#
# 2023-04-18 22:05:59 : Computing Pairwise Tests (1 of 1), 0.063 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 22:06:46 : Completed Pairwise Tests, 0.848 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc71e095066-Date-2023-04-18_Time-22-05-55.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc773afe03e-Date-2023-04-18_Time-22-06-48.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:06:48 : Matching Known Biases, 0.008 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 43
#
# 2023-04-18 22:06:49 :
#
# 2023-04-18 22:06:52 : Computing Pairwise Tests (1 of 1), 0.065 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 22:07:47 : Completed Pairwise Tests, 0.976 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc773afe03e-Date-2023-04-18_Time-22-06-48.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc753dce9e6-Date-2023-04-18_Time-22-08-18.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:08:19 : Matching Known Biases, 0.009 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 15
#
# 2023-04-18 22:08:19 :
#
# 2023-04-18 22:08:24 : Computing Pairwise Tests (1 of 1), 0.096 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-04-18 22:09:14 : Completed Pairwise Tests, 0.929 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc753dce9e6-Date-2023-04-18_Time-22-08-18.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc71f2584b7-Date-2023-04-18_Time-22-09-17.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:09:18 : Matching Known Biases, 0.008 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 15
#
# 2023-04-18 22:09:18 :
#
# 2023-04-18 22:09:23 : Computing Pairwise Tests (1 of 1), 0.093 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 22:10:11 : Completed Pairwise Tests, 0.897 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc71f2584b7-Date-2023-04-18_Time-22-09-17.log
#
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-3bdc74a7069c7-Date-2023-04-18_Time-22-10-13.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-04-18 22:10:15 : Matching Known Biases, 0.008 mins elapsed.
#
# Found less than 100 cells for background matching, Lowering k to 49
#
# 2023-04-18 22:10:15 :
#
# 2023-04-18 22:10:20 : Computing Pairwise Tests (1 of 1), 0.091 mins elapsed.
#
# Pairwise Test Methamphetamine : Seqnames chr1
#
# Pairwise Test Methamphetamine : Seqnames chr10
#
# Pairwise Test Methamphetamine : Seqnames chr11
#
# Pairwise Test Methamphetamine : Seqnames chr12
#
# Pairwise Test Methamphetamine : Seqnames chr13
#
# Pairwise Test Methamphetamine : Seqnames chr14
#
# Pairwise Test Methamphetamine : Seqnames chr15
#
# Pairwise Test Methamphetamine : Seqnames chr16
#
# Pairwise Test Methamphetamine : Seqnames chr17
#
# Pairwise Test Methamphetamine : Seqnames chr18
#
# Pairwise Test Methamphetamine : Seqnames chr19
#
# Pairwise Test Methamphetamine : Seqnames chr2
#
# Pairwise Test Methamphetamine : Seqnames chr20
#
# Pairwise Test Methamphetamine : Seqnames chr3
#
# Pairwise Test Methamphetamine : Seqnames chr4
#
# Pairwise Test Methamphetamine : Seqnames chr5
#
# Pairwise Test Methamphetamine : Seqnames chr6
#
# Pairwise Test Methamphetamine : Seqnames chr7
#
# Pairwise Test Methamphetamine : Seqnames chr8
#
# Pairwise Test Methamphetamine : Seqnames chr9
#
# Pairwise Test Methamphetamine : Seqnames chrX
#
# ###########
# 2023-04-18 22:11:22 : Completed Pairwise Tests, 1.128 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-3bdc74a7069c7-Date-2023-04-18_Time-22-10-13.log

# %%
table(proj2$Sire)
# Out:
#         Cocaine Methamphetamine          Saline
#             178             558             162

# %%
markerTest_CvS <- getMarkerFeatures(
  ArchRProj = proj2, 
  useMatrix = "PeakMatrix",
  groupBy = "Sire",
  testMethod = "wilcoxon",
  bias = c("TSSEnrichment", "log10(nFrags)"),
  useGroups = "Cocaine",
  bgdGroups = "Saline"
)
# Out:
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-1135c6fc96363-Date-2023-02-07_Time-09-26-53.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# 2023-02-07 09:26:54 : Matching Known Biases, 0.017 mins elapsed.
#
# 2023-02-07 09:27:02 : Computing Pairwise Tests (1 of 1), 0.152 mins elapsed.
#
# Pairwise Test Cocaine : Seqnames chr1
#
# Pairwise Test Cocaine : Seqnames chr10
#
# Pairwise Test Cocaine : Seqnames chr11
#
# Pairwise Test Cocaine : Seqnames chr12
#
# Pairwise Test Cocaine : Seqnames chr13
#
# Pairwise Test Cocaine : Seqnames chr14
#
# Pairwise Test Cocaine : Seqnames chr15
#
# Pairwise Test Cocaine : Seqnames chr16
#
# Pairwise Test Cocaine : Seqnames chr17
#
# Pairwise Test Cocaine : Seqnames chr18
#
# Pairwise Test Cocaine : Seqnames chr19
#
# Pairwise Test Cocaine : Seqnames chr2
#
# Pairwise Test Cocaine : Seqnames chr20
#
# Pairwise Test Cocaine : Seqnames chr3
#
# Pairwise Test Cocaine : Seqnames chr4
#
# Pairwise Test Cocaine : Seqnames chr5
#
# Pairwise Test Cocaine : Seqnames chr6
#
# Pairwise Test Cocaine : Seqnames chr7
#
# Pairwise Test Cocaine : Seqnames chr8
#
# Pairwise Test Cocaine : Seqnames chr9
#
# Pairwise Test Cocaine : Seqnames chrX
#
# ###########
# 2023-02-07 09:27:43 : Completed Pairwise Tests, 0.832 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-1135c6fc96363-Date-2023-02-07_Time-09-26-53.log

# %%
test_list = list('Cocaine_v_Saline' = markerTest_CvS,
                'Meth_v_Saline' = markerTest_MvS, ..)
path = file.path(other_places, paste0('differential_PeakMatrix.', make.names(cellType), '.rds'))
saveRDS(test_list, path)
# Out:
# class: SummarizedExperiment
# dim: 466022 1
# metadata(2): MatchInfo Params
# assays(7): Log2FC Mean ... AUC MeanBGD
# rownames(466022): 1 2 ... 466021 466022
# rowData names(4): seqnames idx start end
# colnames(1): Cocaine
# colData names(0):

# %%
assays(markerTest)$Log2FC %>% head()
rowData(markerTest)
# Out:
#   Cocaine
# 1  0.000000
# 2 -2.295078
# 3  0.000000
# 4  1.359338
# 5  1.916263
# 6  2.661691
# DataFrame with 466022 rows and 4 columns
#        seqnames     idx     start       end
#           <Rle> <array>   <array>   <array>
# 1          chr1       1    482455    482955
# 2          chr1       2    577755    578255
# 3          chr1       3    589712    590212
# 4          chr1       4    595207    595707
# 5          chr1       5    595781    596281
# ...         ...     ...       ...       ...
# 466018     chrX    3762 152265233 152265733
# 466019     chrX    3763 152267219 152267719
# 466020     chrX    3764 152268353 152268853
# 466021     chrX    3765 152268882 152269382
# 466022     chrX    3766 152310062 152310562
